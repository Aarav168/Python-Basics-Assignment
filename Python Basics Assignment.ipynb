# %%
# 1.Explain the key features of Python that make it a popular choice for programming?

def python_features():
    features = {
        "1. Easy to Learn and Use": "Python has a simple and clean syntax, making it beginner-friendly.",
        "2. Interpreted Language": "Python code is executed line by line, making debugging easier.",
        "3. Dynamically Typed": "You don't need to declare data types explicitly.",
        "4. High-Level Language": "Python handles complex tasks like memory management automatically.",
        "5. Extensive Standard Library": "Python comes with a wide range of modules and libraries for various tasks.",
        "6. Cross-Platform": "Python works on different operating systems like Windows, macOS, and Linux.",
        "7. Open Source": "Python is free to use and has a large, active community.",
        "8. Object-Oriented and Functional": "Supports both OOP and functional programming paradigms.",
        "9. Vast Ecosystem": "Popular libraries for web development, data science, AI, etc. (e.g., Django, NumPy, TensorFlow).",
        "10. Embeddable and Extensible": "You can embed Python in other languages like C/C++ or extend it with them."
    }
    
    for key, value in features.items():
        print(f"{key} ➜ {value}")

# Call the function to display features
python_features()
# Out:
# 1. Easy to Learn and Use ➜ Python has a simple and clean syntax, making it beginner-friendly.
# 2. Interpreted Language ➜ Python code is executed line by line, making debugging easier.
# 3. Dynamically Typed ➜ You don't need to declare data types explicitly.
# 4. High-Level Language ➜ Python handles complex tasks like memory management automatically.
# 5. Extensive Standard Library ➜ Python comes with a wide range of modules and libraries for various tasks.
# 6. Cross-Platform ➜ Python works on different operating systems like Windows, macOS, and Linux.
# 7. Open Source ➜ Python is free to use and has a large, active community.
# 8. Object-Oriented and Functional ➜ Supports both OOP and functional programming paradigms.
# 9. Vast Ecosystem ➜ Popular libraries for web development, data science, AI, etc. (e.g., Django, NumPy, TensorFlow).
# 10. Embeddable and Extensible ➜ You can embed Python in other languages like C/C++ or extend it with them.

# %%
# 2.Describe the role of predefined keywords in Python and provide examples of how they are used in a program?


def keyword_explanation():
    explanation = (
        "In Python, predefined keywords (also known as reserved words) are words that have special meaning. "
        "They are part of the syntax and cannot be used as identifiers (like variable or function names). "
        "These keywords control the structure and flow of a program."
    )
    print(explanation)
    
    # Example usage of some common keywords
    print("\nExamples of Python keywords:")

    # if-else keyword usage
    x = 10
    if x > 5:
        print("x is greater than 5")  # using 'if'
    else:
        print("x is less than or equal to 5")  # using 'else'

    # for keyword usage
    for i in range(3):  # using 'for' and 'in'
        print(f"Loop iteration {i}")

    # def and return keyword usage
    def greet(name):  # using 'def'
        return f"Hello, {name}!"  # using 'return'

    print(greet("Alice"))

    # import keyword usage
    import math  # using 'import'
    print("Square root of 16 is:", math.sqrt(16))

# Call the function
keyword_explanation()
# Out:
# In Python, predefined keywords (also known as reserved words) are words that have special meaning. They are part of the syntax and cannot be used as identifiers (like variable or function names). These keywords control the structure and flow of a program.
#
# Examples of Python keywords:
# x is greater than 5
# Loop iteration 0
# Loop iteration 1
# Loop iteration 2
# Hello, Alice!
# Square root of 16 is: 4.0

# %%
# 3.Compare and contrast mutable and immutable objects in Python with examples?

def mutable_vs_immutable():
    print("🔁 Mutable Objects:")
    print("- Can be changed after creation.")
    print("- Examples: list, dict, set")

    # Mutable Example: List
    my_list = [1, 2, 3]
    print("Original List:", my_list)
    my_list.append(4)
    print("Modified List (after append):", my_list)

    print("\n🔒 Immutable Objects:")
    print("- Cannot be changed after creation.")
    print("- Examples: int, float, string, tuple")

    # Immutable Example: String
    my_string = "hello"
    print("Original String:", my_string)
    new_string = my_string.replace("h", "y")
    print("Modified String (using replace):", new_string)
    print("Original String remains unchanged:", my_string)

    # Immutable Example: Tuple
    my_tuple = (1, 2, 3)
    print("Tuple:", my_tuple)
    try:
        my_tuple[0] = 100  # This will raise an error
    except TypeError as e:
        print("Error when trying to modify tuple:", e)

# Call the function
mutable_vs_immutable()
# Out:
# 🔁 Mutable Objects:
# - Can be changed after creation.
# - Examples: list, dict, set
# Original List: [1, 2, 3]
# Modified List (after append): [1, 2, 3, 4]
#
# 🔒 Immutable Objects:
# - Cannot be changed after creation.
# - Examples: int, float, string, tuple
# Original String: hello
# Modified String (using replace): yello
# Original String remains unchanged: hello
# Tuple: (1, 2, 3)
# Error when trying to modify tuple: 'tuple' object does not support item assignment

# %%
# 4.Discuss the different types of operators in Python and provide examples of how they are used?

def python_operators():
    print("🔹 1. Arithmetic Operators")
    a, b = 10, 3
    print("Addition:", a + b)        # +
    print("Subtraction:", a - b)     # -
    print("Multiplication:", a * b)  # *
    print("Division:", a / b)        # /
    print("Modulus:", a % b)         # %
    print("Exponent:", a ** b)       # **
    print("Floor Division:", a // b) # //

    print("\n🔹 2. Comparison Operators")
    print("Equal:", a == b)          # ==
    print("Not Equal:", a != b)      # !=
    print("Greater Than:", a > b)    # >
    print("Less Than:", a < b)       # <
    print("Greater or Equal:", a >= b)  # >=
    print("Less or Equal:", a <= b)     # <=

    print("\n🔹 3. Logical Operators")
    x, y = True, False
    print("AND:", x and y)           # and
    print("OR:", x or y)             # or
    print("NOT:", not x)             # not

    print("\n🔹 4. Assignment Operators")
    num = 5
    num += 2  # same as num = num + 2
    print("+= Operator:", num)
    num *= 3  # same as num = num * 3
    print("*= Operator:", num)

    print("\n🔹 5. Bitwise Operators")
    x, y = 5, 3  # binary: 101 & 011
    print("AND (&):", x & y)
    print("OR (|):", x | y)
    print("XOR (^):", x ^ y)
    print("Left Shift (<<):", x << 1)
    print("Right Shift (>>):", x >> 1)

    print("\n🔹 6. Membership Operators")
    lst = [1, 2, 3, 4]
    print("3 in list:", 3 in lst)
    print("5 not in list:", 5 not in lst)

    print("\n🔹 7. Identity Operators")
    a = [1, 2]
    b = a
    c = [1, 2]
    print("a is b:", a is b)         # True (same object)
    print("a is c:", a is c)         # False (same value, different objects)
    print("a == c:", a == c)         # True (same content)

# Call the function
python_operators()
# Out:
# 🔹 1. Arithmetic Operators
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Modulus: 1
# Exponent: 1000
# Floor Division: 3
#
# 🔹 2. Comparison Operators
# Equal: False
# Not Equal: True
# Greater Than: True
# Less Than: False
# Greater or Equal: True
# Less or Equal: False
#
# 🔹 3. Logical Operators
# AND: False
# OR: True
# NOT: False
#
# 🔹 4. Assignment Operators
# += Operator: 7
# *= Operator: 21
#
# 🔹 5. Bitwise Operators
# AND (&): 1
# OR (|): 7
# XOR (^): 6
# Left Shift (<<): 10
# Right Shift (>>): 2
#
# 🔹 6. Membership Operators
# 3 in list: True
# 5 not in list: True
#
# 🔹 7. Identity Operators
# a is b: True
# a is c: False
# a == c: True

# %%
# 5.Explain the concept of type casting in Python with examples?

def type_casting_examples():
    print("📘 Type Casting: Converting one data type to another.")

    print("\n🔹 1. Implicit Type Casting (Python does it automatically)")
    int_num = 10
    float_num = 2.5
    result = int_num + float_num  # int is automatically converted to float
    print("int_num + float_num =", result)
    print("Type of result:", type(result))

    print("\n🔹 2. Explicit Type Casting (Done manually by the programmer)")

    # int() – Converts to integer
    x = "100"
    int_x = int(x)
    print("String to int:", int_x, "| Type:", type(int_x))

    # float() – Converts to float
    y = "12.34"
    float_y = float(y)
    print("String to float:", float_y, "| Type:", type(float_y))

    # str() – Converts to string
    z = 456
    str_z = str(z)
    print("Integer to string:", str_z, "| Type:", type(str_z))

    # list(), tuple(), set() – Convert between collections
    my_tuple = (1, 2, 3)
    my_list = list(my_tuple)
    print("Tuple to List:", my_list)

    my_list2 = [4, 5, 6]
    my_set = set(my_list2)
    print("List to Set:", my_set)

# Call the function
type_casting_examples()
# Out:
# 📘 Type Casting: Converting one data type to another.
#
# 🔹 1. Implicit Type Casting (Python does it automatically)
# int_num + float_num = 12.5
# Type of result: <class 'float'>
#
# 🔹 2. Explicit Type Casting (Done manually by the programmer)
# String to int: 100 | Type: <class 'int'>
# String to float: 12.34 | Type: <class 'float'>
# Integer to string: 456 | Type: <class 'str'>
# Tuple to List: [1, 2, 3]
# List to Set: {4, 5, 6}

# %%
# 6.How do conditional statements work in Python? Illustrate with examples?

def conditional_statements():
    print("📘 Conditional statements are used to make decisions in Python.")

    print("\n🔹 if statement")
    num = 10
    if num > 0:
        print("num is positive")

    print("\n🔹 if-else statement")
    num = -5
    if num >= 0:
        print("num is non-negative")
    else:
        print("num is negative")

    print("\n🔹 if-elif-else statement")
    score = 85
    if score >= 90:
        print("Grade: A")
    elif score >= 80:
        print("Grade: B")
    elif score >= 70:
        print("Grade: C")
    else:
        print("Grade: F")

    print("\n🔹 Nested if statement")
    age = 20
    if age >= 18:
        if age < 21:
            print("You are an adult but not allowed to drink in the US.")
        else:
            print("You are an adult and allowed to drink.")
    else:
        print("You are underage.")

# Call the function
conditional_statements()
# Out:
# 📘 Conditional statements are used to make decisions in Python.
#
# 🔹 if statement
# num is positive
#
# 🔹 if-else statement
# num is negative
#
# 🔹 if-elif-else statement
# Grade: B
#
# 🔹 Nested if statement
# You are an adult but not allowed to drink in the US.

# %%
# 7.Describe the different types of loops in Python and their use cases with examples?

def python_loops():
    print("🔁 Loops in Python are used to execute a block of code repeatedly.")

    print("\n🔹 1. for loop")
    print("Use Case: Iterating over a sequence like list, tuple, string.")
    fruits = ["apple", "banana", "cherry"]
    for fruit in fruits:
        print("Fruit:", fruit)

    print("\n🔹 2. for loop with range()")
    print("Use Case: Repeating code a specific number of times.")
    for i in range(3):
        print("Loop iteration:", i)

    print("\n🔹 3. while loop")
    print("Use Case: Run a block of code as long as a condition is true.")
    count = 0
    while count < 3:
        print("Count is:", count)
        count += 1

    print("\n🔹 4. Nested Loops")
    print("Use Case: Loop inside another loop (e.g., 2D structures).")
    for i in range(2):
        for j in range(3):
            print(f"i={i}, j={j}")

    print("\n🔹 5. Loop Control Statements")
    print("Use Case: Modify loop behavior using break, continue, pass")

    print("\n🔸 break example:")
    for i in range(5):
        if i == 3:
            break
        print(i)

    print("\n🔸 continue example:")
    for i in range(5):
        if i == 2:
            continue
        print(i)

    print("\n🔸 pass example:")
    for i in range(3):
        pass  # Placeholder when no action is needed
    print("Loop with 'pass' ran successfully.")

# Call the function
python_loops()
# Out:
# 🔁 Loops in Python are used to execute a block of code repeatedly.
#
# 🔹 1. for loop
# Use Case: Iterating over a sequence like list, tuple, string.
# Fruit: apple
# Fruit: banana
# Fruit: cherry
#
# 🔹 2. for loop with range()
# Use Case: Repeating code a specific number of times.
# Loop iteration: 0
# Loop iteration: 1
# Loop iteration: 2
#
# 🔹 3. while loop
# Use Case: Run a block of code as long as a condition is true.
# Count is: 0
# Count is: 1
# Count is: 2
#
# 🔹 4. Nested Loops
# Use Case: Loop inside another loop (e.g., 2D structures).
# i=0, j=0
# i=0, j=1
# i=0, j=2
# i=1, j=0
# i=1, j=1
# i=1, j=2
#
# 🔹 5. Loop Control Statements
# Use Case: Modify loop behavior using break, continue, pass
#
# 🔸 break example:
# 0
# 1
# 2
#
# 🔸 continue example:
# 0
# 1
# 3
# 4
#
# 🔸 pass example:
# Loop with 'pass' ran successfully.
